# %% [markdown]
# #### Exercise 1
# ##### Using the data in the `2019_Yellow_Taxi_Trip_Data.csv` file, calculate summary statistics for the `fare_amount`, `tip_amount`, `tolls_amount`, and `total_amount` columns.

# %%
import pandas as pd

# %%
df = pd.read_csv("data/2019_Yellow_Taxi_Trip_Data.csv")

df.head()
# Out:
#    vendorid     tpep_pickup_datetime    tpep_dropoff_datetime  \
# 0         2  2019-10-23T16:39:42.000  2019-10-23T17:14:10.000
# 1         1  2019-10-23T16:32:08.000  2019-10-23T16:45:26.000
# 2         2  2019-10-23T16:08:44.000  2019-10-23T16:21:11.000
# 3         2  2019-10-23T16:22:44.000  2019-10-23T16:43:26.000
# 4         2  2019-10-23T16:45:11.000  2019-10-23T16:58:49.000
#
#    passenger_count  trip_distance  ratecodeid store_and_fwd_flag  \
# 0                1           7.93           1                  N
# 1                1           2.00           1                  N
# 2                1           1.36           1                  N
# 3                1           1.00           1                  N
# 4                1           1.96           1                  N
#
#    pulocationid  dolocationid  payment_type  fare_amount  extra  mta_tax  \
# 0           138           170             1         29.5    1.0      0.5
# 1            11            26             1         10.5    1.0      0.5
# 2           163           162             1          9.5    1.0      0.5
# 3           170           163             1         13.0    1.0      0.5
# 4           163           236             1         10.5    1.0      0.5
#
#    tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 0        7.98          6.12                    0.3         47.90
# 1        0.00          0.00                    0.3         12.30
# 2        2.00          0.00                    0.3         15.80
# 3        4.32          0.00                    0.3         21.62
# 4        0.50          0.00                    0.3         15.30
#
#    congestion_surcharge
# 0                   2.5
# 1                   0.0
# 2                   2.5
# 3                   2.5
# 4                   2.5

# %%
print("min = ", df["fare_amount"].min())
print("mean = ",df["fare_amount"].mean())
print("mean = ",df["fare_amount"].median())
print("min = ", df["fare_amount"].max())
# Out:
# min =  -52.0
# mean =  15.106313
# mean =  10.0
# min =  176.0

# %%
print("min = ", df["tip_amount"].min())
print("mean = ",df["tip_amount"].mean())
print("mean = ",df["tip_amount"].median())
print("min = ", df["tip_amount"].max())
# Out:
# min =  0.0
# mean =  2.6344939999999997
# mean =  2.0
# min =  43.0

# %%
print("min = ", df["tolls_amount"].min())
print("mean = ",df["tolls_amount"].mean())
print("mean = ",df["tolls_amount"].median())
print("min = ", df["tolls_amount"].max())
# Out:
# min =  -6.12
# mean =  0.623447
# mean =  0.0
# min =  612.0

# %%
print("min = ", df["total_amount"].min())
print("mean = ",df["total_amount"].mean())
print("mean = ",df["total_amount"].median())
print("min = ", df["total_amount"].max())
# Out:
# min =  -65.92
# mean =  22.564659
# mean =  16.3
# min =  671.8

# %% [markdown]
# #### Exercise 2
# ##### Isolate the `fare_amount`, `tip_amount`, `tolls_amount`, and `total_amount` for the longest trip by distance (`trip_distance`).

# %%
df.loc[df["trip_distance"].idxmax(), ["fare_amount","tip_amount","tolls_amount","total_amount"]]
# Out:
# fare_amount      176.0
# tip_amount       18.29
# tolls_amount      6.12
# total_amount    201.21
# Name: 8338, dtype: object

# %% [markdown]
# #### Exercise 3
# ##### Read in the meteorite data from the `Meteorite_Landings.csv` file, rename the `mass (g)` column to `mass`, and drop all the latitude and longitude columns. Sort the result by mass in descending order.

# %%
df1 = pd.read_csv("data/Meteorite_Landings.csv")

df1.head()
# Out:
#        name   id nametype     recclass  mass (g)  fall  \
# 0    Aachen    1    Valid           L5      21.0  Fell
# 1    Aarhus    2    Valid           H6     720.0  Fell
# 2      Abee    6    Valid          EH4  107000.0  Fell
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell
# 4   Achiras  370    Valid           L6     780.0  Fell
#
#                      year    reclat    reclong           GeoLocation
# 0  01/01/1880 12:00:00 AM  50.77500    6.08333     (50.775, 6.08333)
# 1  01/01/1951 12:00:00 AM  56.18333   10.23333  (56.18333, 10.23333)
# 2  01/01/1952 12:00:00 AM  54.21667 -113.00000    (54.21667, -113.0)
# 3  01/01/1976 12:00:00 AM  16.88333  -99.90000     (16.88333, -99.9)
# 4  01/01/1902 12:00:00 AM -33.16667  -64.95000   (-33.16667, -64.95)

# %%
df1.rename(columns={'mass (g)': 'mass'}, inplace=True)

df1.drop(df1.columns[[7, 8]], axis=1, inplace=True)

df1.sort_values(by='mass', inplace=True, ascending=False)

df1.head()
# Out:
#                   name     id nametype      recclass        mass   fall  \
# 16392             Hoba  11890    Valid     Iron, IVB  60000000.0  Found
# 5373         Cape York   5262    Valid   Iron, IIIAB  58200000.0  Found
# 5365   Campo del Cielo   5247    Valid  Iron, IAB-MG  50000000.0  Found
# 5370     Canyon Diablo   5257    Valid  Iron, IAB-MG  30000000.0  Found
# 3455           Armanty   2335    Valid    Iron, IIIE  28000000.0  Found
#
#                          year             GeoLocation
# 16392  01/01/1920 12:00:00 AM   (-19.58333, 17.91667)
# 5373   01/01/1818 12:00:00 AM   (76.13333, -64.93333)
# 5365   12/22/1575 12:00:00 AM  (-27.46667, -60.58333)
# 5370   01/01/1891 12:00:00 AM     (35.05, -111.03333)
# 3455   01/01/1898 12:00:00 AM            (47.0, 88.0)

# %% [markdown]
# #### Exercise 4
# ##### Using the meteorite data from the `Meteorite_Landings.csv` file, update the `year` column to only contain the year, convert it to a numeric data type, and create a new column indicating whether the meteorite was observed falling before 1970. Set the index to the `id` column and extract all the rows with IDs between 10,036 and 10,040 (inclusive) with `loc[]`.
#
# ###### **Hint 1**: Use `year.str.slice()` to grab a substring.
#
# ###### **Hint 2**: Make sure to sort the index before using `loc[]` to select the range.
#
# ###### **Bonus**: There's a data entry error in the `year` column. Can you find it? (Don't spend too much time on this.)

# %%
df1['year'] = pd.to_datetime(df1['year'], errors='coerce')

df1 = df1.dropna(subset=['year'])

df1['year'] = pd.to_datetime(df1['year']).dt.year

df1['isBefore1970'] = df1['year'] < 1970

df1.head()
# Out:
# /tmp/ipykernel_2135/1018244441.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df1['year'] = pd.to_datetime(df1['year'], errors='coerce')
#                 name     id nametype      recclass        mass   fall  year  \
# 16392           Hoba  11890    Valid     Iron, IVB  60000000.0  Found  1920
# 5373       Cape York   5262    Valid   Iron, IIIAB  58200000.0  Found  1818
# 5370   Canyon Diablo   5257    Valid  Iron, IAB-MG  30000000.0  Found  1891
# 3455         Armanty   2335    Valid    Iron, IIIE  28000000.0  Found  1898
# 12613         Gibeon  10912    Valid     Iron, IVA  26000000.0  Found  1836
#
#                  GeoLocation  isBefore1970
# 16392  (-19.58333, 17.91667)          True
# 5373   (76.13333, -64.93333)          True
# 5370     (35.05, -111.03333)          True
# 3455            (47.0, 88.0)          True
# 12613          (-25.5, 18.0)          True

# %%
df1.set_index('id', inplace=True)

df1.sort_index(inplace=True)

# %%
filtered_rows = df1.loc[10036:10040]

print(filtered_rows)
# Out:
#          name nametype         recclass    mass   fall  year  \
# id
# 10036  Enigma    Valid               H4    94.0  Found  1967
# 10037    Enon    Valid  Iron, ungrouped   763.0  Found  1883
# 10038   Enshi    Valid               H5  8000.0   Fell  1974
#
#                  GeoLocation  isBefore1970
# id
# 10036  (31.33333, -82.31667)          True
# 10037     (39.86667, -83.95)          True
# 10038          (30.3, 109.5)         False

# %% [markdown]
# #### Exercise 5
# ##### Using the taxi trip data in the `2019_Yellow_Taxi_Trip_Data.csv` file, resample the data to an hourly frequency based on the dropoff time. Calculate the total `trip_distance`, `fare_amount`, `tolls_amount`, and `tip_amount`, then find the 5 hours with the most tips.

# %%
df2 = pd.read_csv("data/2019_Yellow_Taxi_Trip_Data.csv")

df2.head()
# Out:
#    vendorid     tpep_pickup_datetime    tpep_dropoff_datetime  \
# 0         2  2019-10-23T16:39:42.000  2019-10-23T17:14:10.000
# 1         1  2019-10-23T16:32:08.000  2019-10-23T16:45:26.000
# 2         2  2019-10-23T16:08:44.000  2019-10-23T16:21:11.000
# 3         2  2019-10-23T16:22:44.000  2019-10-23T16:43:26.000
# 4         2  2019-10-23T16:45:11.000  2019-10-23T16:58:49.000
#
#    passenger_count  trip_distance  ratecodeid store_and_fwd_flag  \
# 0                1           7.93           1                  N
# 1                1           2.00           1                  N
# 2                1           1.36           1                  N
# 3                1           1.00           1                  N
# 4                1           1.96           1                  N
#
#    pulocationid  dolocationid  payment_type  fare_amount  extra  mta_tax  \
# 0           138           170             1         29.5    1.0      0.5
# 1            11            26             1         10.5    1.0      0.5
# 2           163           162             1          9.5    1.0      0.5
# 3           170           163             1         13.0    1.0      0.5
# 4           163           236             1         10.5    1.0      0.5
#
#    tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 0        7.98          6.12                    0.3         47.90
# 1        0.00          0.00                    0.3         12.30
# 2        2.00          0.00                    0.3         15.80
# 3        4.32          0.00                    0.3         21.62
# 4        0.50          0.00                    0.3         15.30
#
#    congestion_surcharge
# 0                   2.5
# 1                   0.0
# 2                   2.5
# 3                   2.5
# 4                   2.5

# %%
df2['tpep_dropoff_datetime'] = pd.to_datetime(df2['tpep_dropoff_datetime'])
df2.set_index('tpep_dropoff_datetime', inplace=True)

df2_totals = df2.resample('h').agg({
    'trip_distance': 'sum',
    'fare_amount': 'sum',
    'tolls_amount': 'sum',
    'tip_amount': 'sum'
})

df2_5_mostips = df2_totals.sort_values(by='tip_amount', ascending=False).head(5)

print(df2_5_mostips)
# Out:
#                        trip_distance  fare_amount  tolls_amount  tip_amount
# tpep_dropoff_datetime
# 2019-10-23 16:00:00         10676.95     67797.76        699.04    12228.64
# 2019-10-23 17:00:00         16052.83     70131.91       4044.04    12044.03
# 2019-10-23 18:00:00          3104.56     11565.56       1454.67     1907.64
# 2019-10-23 15:00:00            14.34       213.50          0.00       51.75
# 2019-10-23 19:00:00            98.59       268.00         24.48       25.74

# %% [markdown]
# #### Exercise 6
# ##### Using the TSA traveler throughput data in the `tsa_melted_holiday_travel.csv` file, create box plots for traveler throughput for each year in the data. Hint: Pass `kind='box'` into the `plot()` method to generate box plots.

# %%
df2 = pd.read_csv("data/tsa_melted_holiday_travel.csv")

df2.head()
# Out:
#          date  year  travelers         holiday
# 0  2019-01-01  2019  2126398.0  New Year's Day
# 1  2019-01-02  2019  2345103.0  New Year's Day
# 2  2019-01-03  2019  2202111.0             NaN
# 3  2019-01-04  2019  2150571.0             NaN
# 4  2019-01-05  2019  1975947.0             NaN

# %%
df2.groupby('year')['travelers'].plot(kind='box', legend=True)
# Out:
# year
# 2019    Axes(0.125,0.11;0.775x0.77)
# 2020    Axes(0.125,0.11;0.775x0.77)
# 2021    Axes(0.125,0.11;0.775x0.77)
# Name: travelers, dtype: object

# %% [markdown]
# #### Exercise 7
# ##### Using the TSA traveler throughput data in the `tsa_melted_holiday_travel.csv` file, create a heatmap that shows the 2019 TSA median traveler throughput by day of week and month.

# %%
import seaborn as sns

df2['date'] = pd.to_datetime(df2['date'])

df2['day_of_week'] = df2['date'].dt.dayofweek  
df2['month'] = df2['date'].dt.month

df2_median = df2.groupby(['day_of_week', 'month'])['travelers'].median().reset_index()

df2_pivot = df2_median.pivot(index='day_of_week', columns='month', values='travelers')

sns.heatmap(df2_pivot, cbar_kws={'label': 'Median Travelers'})
# Out:
# <Axes: xlabel='month', ylabel='day_of_week'>
